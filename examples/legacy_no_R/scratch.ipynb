# %%
import pandas as pd

from control_totals.util import Pipeline

p = Pipeline('configs')

# %%
p.get_table('extrapolated_targets')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 p.get_table('extrapolated_targets')
#
# File ~\PythonProjects\PSRC\control_totals\control_totals\util\pipeline.py:78, in Pipeline.get_table(self, table_name)
#      77 def get_table(self, table_name):
# ---> 78     with pd.HDFStore(self.get_hdf5_path(), mode='r') as h5store:
#      79         return h5store.get(table_name)
#
# File c:\Users\JKolberg\PythonProjects\PSRC\control_totals\.venv\Lib\site-packages\pandas\io\pytables.py:597, in HDFStore.__init__(self, path, mode, complevel, complib, fletcher32, **kwargs)
#     595 self._fletcher32 = fletcher32
#     596 self._filters = None
# --> 597 self.open(mode=mode, **kwargs)
#
# File c:\Users\JKolberg\PythonProjects\PSRC\control_totals\.venv\Lib\site-packages\pandas\io\pytables.py:763, in HDFStore.open(self, mode, **kwargs)
#     757     msg = (
#     758         "Cannot open HDF5 file, which is already opened, "
#     759         "even in read-only mode."
#     760     )
#     761     raise ValueError(msg)
# --> 763 self._handle = tables.open_file(self._path, self._mode, **kwargs)
#
# File c:\Users\JKolberg\PythonProjects\PSRC\control_totals\.venv\Lib\site-packages\tables\file.py:325, in open_file(filename, mode, title, root_uep, filters, **kwargs)
#     319             raise ValueError(
#     320                 "The file '%s' is already opened.  Please "
#     321                 "close it before reopening in write mode." % filename
#     322             )
#     324 # Finally, create the File instance, and return it
# --> 325 return File(filename, mode, title, root_uep, filters, **kwargs)
#
# File c:\Users\JKolberg\PythonProjects\PSRC\control_totals\.venv\Lib\site-packages\tables\file.py:811, in File.__init__(self, filename, mode, title, root_uep, filters, **kwargs)
#     808 self.params = params
#     810 # Now, it is time to initialize the File extension
# --> 811 self._g_new(filename, mode, **params)
#     813 # Check filters and set PyTables format version for new files.
#     814 new = self._v_new
#
# File tables/hdf5extension.pyx:499
# --> 499         check_file_access(name, pymode)
#
# File c:\Users\JKolberg\PythonProjects\PSRC\control_totals\.venv\Lib\site-packages\tables\utils.py:172, in check_file_access(filename, mode)
#     169 if mode == "r":
#     170     # The file should be readable.
#     171     if not os.access(path, os.F_OK):
# --> 172         raise FileNotFoundError(f"``{path}`` does not exist")
#     173     if not path.is_file():
#     174         raise IsADirectoryError(f"``{path}`` is not a regular file")
#
# FileNotFoundError: ``C:\Users\JKolberg\PythonProjects\PSRC\control_totals\examples\legacy_no_R\data\pipeline.h5`` does not exist

# %%
with pd.HDFStore("data/pipeline.h5") as store:
    tables = store.keys()
tables
# Out:
# ['/adjusted_emp_change_targets_calculations',
#  '/adjusted_emp_change_targets_no_res_con',
#  '/adjusted_emp_change_targets_res_con',
#  '/adjusted_king_targets',
#  '/adjusted_total_pop_change_targets',
#  '/adjusted_units_change_targets',
#  '/block_2010_control_area_xwalk',
#  '/block_control_area_xwalk',
#  '/blocks',
#  '/blocks_2010',
#  '/control_areas',
#  '/control_target_xwalk',
#  '/control_totals',
#  '/dec_block_data',
#  '/decennial_by_control_area',
#  '/employment_2018_by_control_area',
#  '/employment_2019_by_control_area',
#  '/employment_2020_by_control_area',
#  '/extrapolated_targets',
#  '/king_targets',
#  '/kitsap_targets',
#  '/ofm_block_2019',
#  '/ofm_block_2019_by_control_area',
#  '/ofm_parcel_control_area_xwalk',
#  '/ofm_parcelized_2018',
#  '/ofm_parcelized_2018_by_control_area',
#  '/ofm_parcelized_2019',
#  '/ofm_parcelized_2019_by_control_area',
#  '/ofm_parcelized_2020',
#  '/ofm_parcelized_2020_by_control_area',
#  '/parcel_pts_ofm',
#  '/pierce_targets',
#  '/ref_projection',
#  '/snohomish_targets',
#  '/target_rgid_xwalk']

# %%
p.get_table('split_hct_base_data_2020')
# Out:
#      county_id  nosplit_geo_id               name  split_geo_id  RGID  \
# 0           33               1           Bellevue             1     1
# 1           33               2            Seattle             2     1
# 2           33               3             Auburn             3     2
# 3           33               4            Bothell             4     2
# 4           33               5             Burien             5     2
# ..         ...             ...                ...           ...   ...
# 206         61             138         Mill Creek          1138     3
# 207         61             139    Mill Creek MUGA          1139     3
# 208         61             140  Mountlake Terrace          1140     3
# 209         61             141           Mukilteo          1141     3
# 210         61             142      Mukilteo MUGA          1142     3
#
#      households   persons      jobs
# 0       30833.0   82397.0   42265.0
# 1       88026.0  208484.0  109348.0
# 2       18313.0   50704.0   27248.0
# 3        8268.0   20759.0   12415.0
# 4       11798.0   31290.0    7651.0
# ..          ...       ...       ...
# 206      2255.0    4808.0    4722.0
# 207      1837.0    5154.0    3227.0
# 208      1399.0    3281.0    1797.0
# 209       412.0    1042.0     600.0
# 210       659.0    1959.0    1670.0
#
# [211 rows x 8 columns]

# %%
p.get_table('target_rgid_xwalk')
# Out:
#      target_id             name  county_id  rgid
# 0            1         Bellevue      53033     1
# 1            2          Seattle      53033     1
# 2            3           Auburn      53033     2
# 3            4          Bothell      53033     2
# 4            5           Burien      53033     2
# ..         ...              ...        ...   ...
# 133        170    Snohomish UGA      53061     5
# 134        172     Stanwood UGA      53061     5
# 135        174       Sultan UGA      53061     5
# 136        175     Woodway MUGA      53061     5
# 137        176  Snohomish Rural      53061     6
#
# [138 rows x 4 columns]
