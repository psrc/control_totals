# %%
import pandas as pd

from control_totals.util import Pipeline

# %%
with pd.HDFStore("data/pipeline.h5") as store:
    tables = store.keys()
    df = store['parcels_hct']
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 3
#       1 with pd.HDFStore("data/pipeline.h5") as store:
#       2     tables = store.keys()
# ----> 3     df = store['parcels_hct']
#       4 df
#
# File c:\Users\JKolberg\PythonProjects\control_totals\.venv\Lib\site-packages\pandas\io\pytables.py:615, in HDFStore.__getitem__(self, key)
#     614 def __getitem__(self, key: str):
# --> 615     return self.get(key)
#
# File c:\Users\JKolberg\PythonProjects\control_totals\.venv\Lib\site-packages\pandas\io\pytables.py:825, in HDFStore.get(self, key)
#     823 group = self.get_node(key)
#     824 if group is None:
# --> 825     raise KeyError(f"No object named {key} in the file")
#     826 return self._read_group(group)
#
# KeyError: 'No object named parcels_hct in the file'
