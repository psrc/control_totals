# %% [markdown]
# # Household Size
#
# Average household size = household population / households. Total rows are recomputed from county column sums (not averaged across per-target-area ratios).

# %%
from validation_data_input import show_ratio_county

# %% [markdown]
# ## King County

# %%
show_ratio_county('hhpop', 'hh', 53033, formula='ratio', decimals=2)
# Out:
# ::: {.panel-tabset}
#
# ### Vision 2060 Scaled by County
#
# <style type="text/css">
# </style>
# <table id="T_0adac">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0adac_level0_col0" class="col_heading level0 col0" >2023</th>
#       <th id="T_0adac_level0_col1" class="col_heading level0 col1" >2044</th>
#       <th id="T_0adac_level0_col2" class="col_heading level0 col2" >2060</th>
#       <th id="T_0adac_level0_col3" class="col_heading level0 col3" >Avg. annual change</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >target_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0adac_level0_row0" class="row_heading level0 row0" >Bellevue</th>
#       <td id="T_0adac_row0_col0" class="data row0 col0" >2.46</td>
# ...

# %% [markdown]
# ## Pierce County

# %%
show_ratio_county('hhpop', 'hh', 53053, formula='ratio', decimals=2)
# Out:
# ::: {.panel-tabset}
#
# ### Vision 2060 Scaled by County
#
# <style type="text/css">
# </style>
# <table id="T_a1421">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a1421_level0_col0" class="col_heading level0 col0" >2023</th>
#       <th id="T_a1421_level0_col1" class="col_heading level0 col1" >2044</th>
#       <th id="T_a1421_level0_col2" class="col_heading level0 col2" >2060</th>
#       <th id="T_a1421_level0_col3" class="col_heading level0 col3" >Avg. annual change</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >target_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a1421_level0_row0" class="row_heading level0 row0" >Tacoma</th>
#       <td id="T_a1421_row0_col0" class="data row0 col0" >2.42</td>
# ...

# %% [markdown]
# ## Snohomish County

# %%
show_ratio_county('hhpop', 'hh', 53061, formula='ratio', decimals=2)
# Out:
# ::: {.panel-tabset}
#
# ### Vision 2060 Scaled by County
#
# <style type="text/css">
# </style>
# <table id="T_1a7b9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1a7b9_level0_col0" class="col_heading level0 col0" >2023</th>
#       <th id="T_1a7b9_level0_col1" class="col_heading level0 col1" >2044</th>
#       <th id="T_1a7b9_level0_col2" class="col_heading level0 col2" >2060</th>
#       <th id="T_1a7b9_level0_col3" class="col_heading level0 col3" >Avg. annual change</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >target_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1a7b9_level0_row0" class="row_heading level0 row0" >Everett</th>
#       <td id="T_1a7b9_row0_col0" class="data row0 col0" >2.40</td>
# ...

# %% [markdown]
# ## Kitsap County

# %%
show_ratio_county('hhpop', 'hh', 53035, formula='ratio', decimals=2)
# Out:
# ::: {.panel-tabset}
#
# ### Vision 2060 Scaled by County
#
# <style type="text/css">
# </style>
# <table id="T_b08bc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b08bc_level0_col0" class="col_heading level0 col0" >2023</th>
#       <th id="T_b08bc_level0_col1" class="col_heading level0 col1" >2044</th>
#       <th id="T_b08bc_level0_col2" class="col_heading level0 col2" >2060</th>
#       <th id="T_b08bc_level0_col3" class="col_heading level0 col3" >Avg. annual change</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >target_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b08bc_level0_row0" class="row_heading level0 row0" >Bremerton</th>
#       <td id="T_b08bc_row0_col0" class="data row0 col0" >2.28</td>
# ...
