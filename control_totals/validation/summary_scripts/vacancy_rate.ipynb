# %% [markdown]
# # Vacancy Rate
#
# Vacancy rate = 1 - households / housing units. Spreadsheet forecasts have no units data and will display "Not available".

# %%
from validation_data_input import show_ratio_county

# %% [markdown]
# ## King County

# %%
show_ratio_county('hh', 'units', 53033, formula='vacancy', decimals=3)
# Out:
# ::: {.panel-tabset}
#
# ### Vision 2060 Scaled by County
#
# <style type="text/css">
# </style>
# <table id="T_10fcc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_10fcc_level0_col0" class="col_heading level0 col0" >2023</th>
#       <th id="T_10fcc_level0_col1" class="col_heading level0 col1" >2044</th>
#       <th id="T_10fcc_level0_col2" class="col_heading level0 col2" >2060</th>
#       <th id="T_10fcc_level0_col3" class="col_heading level0 col3" >Avg. annual change</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >target_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_10fcc_level0_row0" class="row_heading level0 row0" >Bellevue</th>
#       <td id="T_10fcc_row0_col0" class="data row0 col0" >0.062</td>
# ...

# %% [markdown]
# ## Pierce County

# %%
show_ratio_county('hh', 'units', 53053, formula='vacancy', decimals=3)
# Out:
# ::: {.panel-tabset}
#
# ### Vision 2060 Scaled by County
#
# <style type="text/css">
# </style>
# <table id="T_6144b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6144b_level0_col0" class="col_heading level0 col0" >2023</th>
#       <th id="T_6144b_level0_col1" class="col_heading level0 col1" >2044</th>
#       <th id="T_6144b_level0_col2" class="col_heading level0 col2" >2060</th>
#       <th id="T_6144b_level0_col3" class="col_heading level0 col3" >Avg. annual change</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >target_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6144b_level0_row0" class="row_heading level0 row0" >Tacoma</th>
#       <td id="T_6144b_row0_col0" class="data row0 col0" >0.059</td>
# ...

# %% [markdown]
# ## Snohomish County

# %%
show_ratio_county('hh', 'units', 53061, formula='vacancy', decimals=3)
# Out:
# ::: {.panel-tabset}
#
# ### Vision 2060 Scaled by County
#
# <style type="text/css">
# </style>
# <table id="T_c1fa3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c1fa3_level0_col0" class="col_heading level0 col0" >2023</th>
#       <th id="T_c1fa3_level0_col1" class="col_heading level0 col1" >2044</th>
#       <th id="T_c1fa3_level0_col2" class="col_heading level0 col2" >2060</th>
#       <th id="T_c1fa3_level0_col3" class="col_heading level0 col3" >Avg. annual change</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >target_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c1fa3_level0_row0" class="row_heading level0 row0" >Everett</th>
#       <td id="T_c1fa3_row0_col0" class="data row0 col0" >0.053</td>
# ...

# %% [markdown]
# ## Kitsap County

# %%
show_ratio_county('hh', 'units', 53035, formula='vacancy', decimals=3)
# Out:
# ::: {.panel-tabset}
#
# ### Vision 2060 Scaled by County
#
# <style type="text/css">
# </style>
# <table id="T_b9a45">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b9a45_level0_col0" class="col_heading level0 col0" >2023</th>
#       <th id="T_b9a45_level0_col1" class="col_heading level0 col1" >2044</th>
#       <th id="T_b9a45_level0_col2" class="col_heading level0 col2" >2060</th>
#       <th id="T_b9a45_level0_col3" class="col_heading level0 col3" >Avg. annual change</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >target_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b9a45_level0_row0" class="row_heading level0 row0" >Bremerton</th>
#       <td id="T_b9a45_row0_col0" class="data row0 col0" >0.089</td>
# ...
