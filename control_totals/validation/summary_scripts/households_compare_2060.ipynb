# %% [markdown]
# # Households comparison - 2060
#
# Pairwise comparison of total households at **2060** between forecasts, by control/target area and grouped by county. Each section shows two tables, both against the same baseline:
#
# - **A vs B**: Vision 2060 Scaled vs Vision 2060
# - **C vs B**: Vision 2060 Scaled (County) vs Vision 2060
#
# `% Diff = (forecast - baseline) / baseline * 100`.

# %%
from comparison_helpers import compare_hh_target_area, compare_hh_region

FORECAST_A = 'vision_2060_scaled'
FORECAST_B = 'vision_2060'  # baseline (denominator)
FORECAST_C = 'vision_2060_scaled_by_county'
YEAR = '2060'

# %% [markdown]
# ## Region

# %%
compare_hh_region(FORECAST_A, FORECAST_B, YEAR)
# Out:
# <style type="text/css">
# #T_b4639 th {
#   background-color: rgba(0,85,140,0.08);
#   font-weight: 600;
#   text-align: left;
# }
# #T_b4639 td {
#   padding: 4px 10px;
# }
# #T_b4639_row0_col3, #T_b4639_row1_col3, #T_b4639_row3_col3, #T_b4639_row4_col3 {
#   color: #2f7a2f;
# }
# #T_b4639_row2_col3 {
#   color: #d97706;
# }
# </style>
# <table id="T_b4639">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b4639_level0_col0" class="col_heading level0 col0" >Vision 2060 Scaled</th>
#       <th id="T_b4639_level0_col1" class="col_heading level0 col1" >Vision 2060</th>
#       <th id="T_b4639_level0_col2" class="col_heading level0 col2" >Diff</th>
#       <th id="T_b4639_level0_col3" class="col_heading level0 col3" >% Diff</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b4639_level0_row0" class="row_heading level0 row0" >King</th>
#       <td id="T_b4639_row0_col0" class="data row0 col0" >1,264,732</td>
# ...

# %%
compare_hh_region(FORECAST_C, FORECAST_B, YEAR)
# Out:
# <style type="text/css">
# #T_f7401 th {
#   background-color: rgba(0,85,140,0.08);
#   font-weight: 600;
#   text-align: left;
# }
# #T_f7401 td {
#   padding: 4px 10px;
# }
# #T_f7401_row0_col3, #T_f7401_row1_col3, #T_f7401_row2_col3, #T_f7401_row3_col3 {
#   color: #b00020;
#   font-weight: 600;
# }
# #T_f7401_row4_col3 {
#   color: #2f7a2f;
# }
# </style>
# <table id="T_f7401">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f7401_level0_col0" class="col_heading level0 col0" >Vision 2060 Scaled by County</th>
#       <th id="T_f7401_level0_col1" class="col_heading level0 col1" >Vision 2060</th>
#       <th id="T_f7401_level0_col2" class="col_heading level0 col2" >Diff</th>
#       <th id="T_f7401_level0_col3" class="col_heading level0 col3" >% Diff</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f7401_level0_row0" class="row_heading level0 row0" >King</th>
# ...

# %% [markdown]
# ## King County

# %%
compare_hh_target_area(FORECAST_A, FORECAST_B, YEAR, 53033)
# Out:
# <style type="text/css">
# #T_2e012 th {
#   background-color: rgba(0,85,140,0.08);
#   font-weight: 600;
#   text-align: left;
# }
# #T_2e012 td {
#   padding: 4px 10px;
# }
# #T_2e012_row0_col3, #T_2e012_row2_col3, #T_2e012_row3_col3, #T_2e012_row4_col3, #T_2e012_row9_col3, #T_2e012_row10_col3, #T_2e012_row11_col3, #T_2e012_row12_col3, #T_2e012_row23_col3, #T_2e012_row27_col3, #T_2e012_row28_col3, #T_2e012_row30_col3, #T_2e012_row38_col3, #T_2e012_row41_col3, #T_2e012_row44_col3, #T_2e012_row47_col3, #T_2e012_row49_col3, #T_2e012_row51_col3 {
#   color: #d97706;
# }
# ...

# %%
compare_hh_target_area(FORECAST_C, FORECAST_B, YEAR, 53033)
# Out:
# <style type="text/css">
# #T_aa168 th {
#   background-color: rgba(0,85,140,0.08);
#   font-weight: 600;
#   text-align: left;
# }
# #T_aa168 td {
#   padding: 4px 10px;
# }
# #T_aa168_row0_col3, #T_aa168_row2_col3, #T_aa168_row3_col3, #T_aa168_row4_col3, #T_aa168_row5_col3, #T_aa168_row7_col3, #T_aa168_row8_col3, #T_aa168_row9_col3, #T_aa168_row10_col3, #T_aa168_row11_col3, #T_aa168_row12_col3, #T_aa168_row13_col3, #T_aa168_row15_col3, #T_aa168_row16_col3, #T_aa168_row17_col3, #T_aa168_row18_col3, #T_aa168_row19_col3, #T_aa168_row23_col3, #T_aa168_row24_col3, #T_aa168_row25_col3, #T_aa168_row27_col3, #T_aa168_row28_col3, #T_aa168_row30_col3, #T_aa168_row36_col3, #T_aa168_row38_col3, #T_aa168_row41_col3, #T_aa168_row44_col3, #T_aa168_row45_col3, #T_aa168_row46_col3, #T_aa168_row47_col3, #T_aa168_row49_col3, #T_aa168_row50_col3, #T_aa168_row51_col3, #T_aa168_row52_col3, #T_aa168_row56_col3 {
#   color: #b00020;
#   font-weight: 600;
# }
# ...

# %% [markdown]
# ## Pierce County

# %%
compare_hh_target_area(FORECAST_A, FORECAST_B, YEAR, 53053)
# Out:
# <style type="text/css">
# #T_153da th {
#   background-color: rgba(0,85,140,0.08);
#   font-weight: 600;
#   text-align: left;
# }
# #T_153da td {
#   padding: 4px 10px;
# }
# #T_153da_row0_col3, #T_153da_row2_col3, #T_153da_row3_col3, #T_153da_row4_col3, #T_153da_row5_col3, #T_153da_row6_col3, #T_153da_row9_col3, #T_153da_row11_col3, #T_153da_row14_col3, #T_153da_row19_col3, #T_153da_row20_col3, #T_153da_row23_col3 {
#   color: #d97706;
# }
# #T_153da_row1_col3, #T_153da_row7_col3, #T_153da_row8_col3, #T_153da_row10_col3, #T_153da_row12_col3, #T_153da_row13_col3, #T_153da_row15_col3, #T_153da_row16_col3, #T_153da_row17_col3, #T_153da_row18_col3, #T_153da_row21_col3, #T_153da_row22_col3, #T_153da_row24_col3, #T_153da_row25_col3, #T_153da_row26_col3 {
#   color: #2f7a2f;
# }
# </style>
# <table id="T_153da">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_153da_level0_col0" class="col_heading level0 col0" >Vision 2060 Scaled</th>
# ...

# %%
compare_hh_target_area(FORECAST_C, FORECAST_B, YEAR, 53053)
# Out:
# <style type="text/css">
# #T_093e8 th {
#   background-color: rgba(0,85,140,0.08);
#   font-weight: 600;
#   text-align: left;
# }
# #T_093e8 td {
#   padding: 4px 10px;
# }
# #T_093e8_row0_col3, #T_093e8_row2_col3, #T_093e8_row3_col3, #T_093e8_row4_col3, #T_093e8_row5_col3, #T_093e8_row6_col3, #T_093e8_row7_col3, #T_093e8_row8_col3, #T_093e8_row9_col3, #T_093e8_row11_col3, #T_093e8_row13_col3, #T_093e8_row14_col3, #T_093e8_row19_col3, #T_093e8_row20_col3, #T_093e8_row23_col3, #T_093e8_row24_col3, #T_093e8_row26_col3 {
#   color: #b00020;
#   font-weight: 600;
# }
# #T_093e8_row1_col3, #T_093e8_row12_col3, #T_093e8_row16_col3, #T_093e8_row17_col3, #T_093e8_row18_col3, #T_093e8_row21_col3, #T_093e8_row22_col3, #T_093e8_row25_col3 {
#   color: #2f7a2f;
# }
# #T_093e8_row10_col3, #T_093e8_row15_col3 {
#   color: #d97706;
# }
# </style>
# <table id="T_093e8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %% [markdown]
# ## Snohomish County

# %%
compare_hh_target_area(FORECAST_A, FORECAST_B, YEAR, 53061)
# Out:
# <style type="text/css">
# #T_a9e36 th {
#   background-color: rgba(0,85,140,0.08);
#   font-weight: 600;
#   text-align: left;
# }
# #T_a9e36 td {
#   padding: 4px 10px;
# }
# #T_a9e36_row0_col3, #T_a9e36_row1_col3, #T_a9e36_row2_col3, #T_a9e36_row3_col3, #T_a9e36_row4_col3, #T_a9e36_row5_col3, #T_a9e36_row7_col3, #T_a9e36_row9_col3, #T_a9e36_row10_col3, #T_a9e36_row12_col3, #T_a9e36_row13_col3, #T_a9e36_row15_col3, #T_a9e36_row19_col3, #T_a9e36_row20_col3, #T_a9e36_row23_col3, #T_a9e36_row24_col3, #T_a9e36_row25_col3, #T_a9e36_row27_col3, #T_a9e36_row33_col3, #T_a9e36_row37_col3, #T_a9e36_row39_col3, #T_a9e36_row40_col3, #T_a9e36_row45_col3 {
#   color: #d97706;
# }
# #T_a9e36_row6_col3, #T_a9e36_row11_col3, #T_a9e36_row14_col3, #T_a9e36_row16_col3, #T_a9e36_row17_col3, #T_a9e36_row18_col3, #T_a9e36_row21_col3, #T_a9e36_row22_col3, #T_a9e36_row26_col3, #T_a9e36_row28_col3, #T_a9e36_row30_col3, #T_a9e36_row32_col3, #T_a9e36_row35_col3, #T_a9e36_row36_col3, #T_a9e36_row44_col3 {
# ...

# %%
compare_hh_target_area(FORECAST_C, FORECAST_B, YEAR, 53061)
# Out:
# <style type="text/css">
# #T_f25b0 th {
#   background-color: rgba(0,85,140,0.08);
#   font-weight: 600;
#   text-align: left;
# }
# #T_f25b0 td {
#   padding: 4px 10px;
# }
# ...

# %% [markdown]
# ## Kitsap County

# %%
compare_hh_target_area(FORECAST_A, FORECAST_B, YEAR, 53035)
# Out:
# <style type="text/css">
# #T_ca67a th {
#   background-color: rgba(0,85,140,0.08);
#   font-weight: 600;
#   text-align: left;
# }
# #T_ca67a td {
#   padding: 4px 10px;
# }
# #T_ca67a_row0_col3, #T_ca67a_row2_col3, #T_ca67a_row5_col3 {
#   color: #d97706;
# }
# #T_ca67a_row1_col3, #T_ca67a_row3_col3, #T_ca67a_row6_col3, #T_ca67a_row7_col3, #T_ca67a_row9_col3, #T_ca67a_row10_col3, #T_ca67a_row11_col3 {
#   color: #2f7a2f;
# }
# #T_ca67a_row4_col3, #T_ca67a_row8_col3 {
#   color: #b00020;
#   font-weight: 600;
# }
# </style>
# <table id="T_ca67a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ca67a_level0_col0" class="col_heading level0 col0" >Vision 2060 Scaled</th>
#       <th id="T_ca67a_level0_col1" class="col_heading level0 col1" >Vision 2060</th>
#       <th id="T_ca67a_level0_col2" class="col_heading level0 col2" >Diff</th>
#       <th id="T_ca67a_level0_col3" class="col_heading level0 col3" >% Diff</th>
#     </tr>
#   </thead>
# ...

# %%
compare_hh_target_area(FORECAST_C, FORECAST_B, YEAR, 53035)
# Out:
# <style type="text/css">
# #T_0dd96 th {
#   background-color: rgba(0,85,140,0.08);
#   font-weight: 600;
#   text-align: left;
# }
# #T_0dd96 td {
#   padding: 4px 10px;
# }
# #T_0dd96_row0_col3, #T_0dd96_row1_col3, #T_0dd96_row2_col3, #T_0dd96_row3_col3, #T_0dd96_row4_col3, #T_0dd96_row5_col3, #T_0dd96_row6_col3, #T_0dd96_row7_col3, #T_0dd96_row8_col3, #T_0dd96_row9_col3, #T_0dd96_row11_col3 {
#   color: #b00020;
#   font-weight: 600;
# }
# #T_0dd96_row10_col3 {
#   color: #2f7a2f;
# }
# </style>
# <table id="T_0dd96">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0dd96_level0_col0" class="col_heading level0 col0" >Vision 2060 Scaled by County</th>
#       <th id="T_0dd96_level0_col1" class="col_heading level0 col1" >Vision 2060</th>
#       <th id="T_0dd96_level0_col2" class="col_heading level0 col2" >Diff</th>
#       <th id="T_0dd96_level0_col3" class="col_heading level0 col3" >% Diff</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# ## Notes
#
# - `% Diff` is computed as `(A - B) / B * 100`, where **B** (baseline) is the
#   second forecast listed at the top of the notebook.
# - Cell color: red when `|% Diff| >= 5%`, amber when `>= 2.5%`, green otherwise.
# - Target areas present in only one forecast still appear, with `-` for the
#   missing forecast's value.
