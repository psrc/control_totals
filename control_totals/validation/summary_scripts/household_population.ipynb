# %% [markdown]
# # Household Population
#
# Population residing in households, by target area and county. Source: `rebased_control_totals_hhpop` or the `HHPop` workbook sheet.

# %%
from validation_data_input import show_indicator_county

# %% [markdown]
# ## King County

# %%
show_indicator_county('hhpop', 53033)
# Out:
# ::: {.panel-tabset}
#
# ### Growth Targets Scaled to REMI by County 2060
#
# <style type="text/css">
# </style>
# <table id="T_da762">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_da762_level0_col0" class="col_heading level0 col0" >2023</th>
#       <th id="T_da762_level0_col1" class="col_heading level0 col1" >2044</th>
#       <th id="T_da762_level0_col2" class="col_heading level0 col2" >2060</th>
#       <th id="T_da762_level0_col3" class="col_heading level0 col3" >Avg. annual change</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >target_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_da762_level0_row0" class="row_heading level0 row0" >Bellevue</th>
#       <td id="T_da762_row0_col0" class="data row0 col0" >152,184</td>
# ...

# %% [markdown]
# ## Pierce County

# %%
show_indicator_county('hhpop', 53053)
# Out:
# ::: {.panel-tabset}
#
# ### Growth Targets Scaled to REMI by County 2060
#
# <style type="text/css">
# </style>
# <table id="T_d4eaa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d4eaa_level0_col0" class="col_heading level0 col0" >2023</th>
#       <th id="T_d4eaa_level0_col1" class="col_heading level0 col1" >2044</th>
#       <th id="T_d4eaa_level0_col2" class="col_heading level0 col2" >2060</th>
#       <th id="T_d4eaa_level0_col3" class="col_heading level0 col3" >Avg. annual change</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >target_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d4eaa_level0_row0" class="row_heading level0 row0" >Tacoma</th>
#       <td id="T_d4eaa_row0_col0" class="data row0 col0" >215,416</td>
# ...

# %% [markdown]
# ## Snohomish County

# %%
show_indicator_county('hhpop', 53061)
# Out:
# ::: {.panel-tabset}
#
# ### Growth Targets Scaled to REMI by County 2060
#
# <style type="text/css">
# </style>
# <table id="T_c3b4d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c3b4d_level0_col0" class="col_heading level0 col0" >2023</th>
#       <th id="T_c3b4d_level0_col1" class="col_heading level0 col1" >2044</th>
#       <th id="T_c3b4d_level0_col2" class="col_heading level0 col2" >2060</th>
#       <th id="T_c3b4d_level0_col3" class="col_heading level0 col3" >Avg. annual change</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >target_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c3b4d_level0_row0" class="row_heading level0 row0" >Everett</th>
#       <td id="T_c3b4d_row0_col0" class="data row0 col0" >110,432</td>
# ...

# %% [markdown]
# ## Kitsap County

# %%
show_indicator_county('hhpop', 53035)
# Out:
# ::: {.panel-tabset}
#
# ### Growth Targets Scaled to REMI by County 2060
#
# <style type="text/css">
# </style>
# <table id="T_a8a3c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a8a3c_level0_col0" class="col_heading level0 col0" >2023</th>
#       <th id="T_a8a3c_level0_col1" class="col_heading level0 col1" >2044</th>
#       <th id="T_a8a3c_level0_col2" class="col_heading level0 col2" >2060</th>
#       <th id="T_a8a3c_level0_col3" class="col_heading level0 col3" >Avg. annual change</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >target_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a8a3c_level0_row0" class="row_heading level0 row0" >Bremerton</th>
#       <td id="T_a8a3c_row0_col0" class="data row0 col0" >38,503</td>
# ...
