# %% [markdown]
# # Region
#
# Four-county PSRC region totals. Each section is a tab-set of forecasts; click a tab name to switch the displayed forecast.

# %%
from validation_data_input import (
    show_region_indicator, show_region_ratio,
)

# %% [markdown]
# ## Population

# %%
show_region_indicator('pop')
# Out:
# ::: {.panel-tabset}
#
# ### Vision 2060 Scaled
#
# <style type="text/css">
# </style>
# <table id="T_f971d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f971d_level0_col0" class="col_heading level0 col0" >2023</th>
#       <th id="T_f971d_level0_col1" class="col_heading level0 col1" >2044</th>
#       <th id="T_f971d_level0_col2" class="col_heading level0 col2" >2060</th>
#       <th id="T_f971d_level0_col3" class="col_heading level0 col3" >Avg. annual change</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >County</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f971d_level0_row0" class="row_heading level0 row0" >King</th>
#       <td id="T_f971d_row0_col0" class="data row0 col0" >2,331,160</td>
# ...

# %% [markdown]
# ## Household Population

# %%
show_region_indicator('hhpop')
# Out:
# ::: {.panel-tabset}
#
# ### Vision 2060 Scaled
#
# <style type="text/css">
# </style>
# <table id="T_7dccb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7dccb_level0_col0" class="col_heading level0 col0" >2023</th>
#       <th id="T_7dccb_level0_col1" class="col_heading level0 col1" >2044</th>
#       <th id="T_7dccb_level0_col2" class="col_heading level0 col2" >2060</th>
#       <th id="T_7dccb_level0_col3" class="col_heading level0 col3" >Avg. annual change</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >County</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7dccb_level0_row0" class="row_heading level0 row0" >King</th>
#       <td id="T_7dccb_row0_col0" class="data row0 col0" >2,294,409</td>
# ...

# %% [markdown]
# ## Households

# %%
show_region_indicator('hh')
# Out:
# ::: {.panel-tabset}
#
# ### Vision 2060 Scaled
#
# <style type="text/css">
# </style>
# <table id="T_c5579">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c5579_level0_col0" class="col_heading level0 col0" >2023</th>
#       <th id="T_c5579_level0_col1" class="col_heading level0 col1" >2044</th>
#       <th id="T_c5579_level0_col2" class="col_heading level0 col2" >2060</th>
#       <th id="T_c5579_level0_col3" class="col_heading level0 col3" >Avg. annual change</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >County</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c5579_level0_row0" class="row_heading level0 row0" >King</th>
#       <td id="T_c5579_row0_col0" class="data row0 col0" >952,892</td>
# ...

# %% [markdown]
# ## Housing Units

# %%
show_region_indicator('units')
# Out:
# ::: {.panel-tabset}
#
# ### Vision 2060 Scaled
#
# <style type="text/css">
# </style>
# <table id="T_e2ff8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e2ff8_level0_col0" class="col_heading level0 col0" >2023</th>
#       <th id="T_e2ff8_level0_col1" class="col_heading level0 col1" >2044</th>
#       <th id="T_e2ff8_level0_col2" class="col_heading level0 col2" >2060</th>
#       <th id="T_e2ff8_level0_col3" class="col_heading level0 col3" >Avg. annual change</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >County</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e2ff8_level0_row0" class="row_heading level0 row0" >King</th>
#       <td id="T_e2ff8_row0_col0" class="data row0 col0" >1,015,762</td>
# ...

# %% [markdown]
# ## Household Size
#
# Household population / households.

# %%
show_region_ratio('hhpop', 'hh', formula='ratio', decimals=2)
# Out:
# ::: {.panel-tabset}
#
# ### Vision 2060 Scaled
#
# <style type="text/css">
# </style>
# <table id="T_248a8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_248a8_level0_col0" class="col_heading level0 col0" >2023</th>
#       <th id="T_248a8_level0_col1" class="col_heading level0 col1" >2044</th>
#       <th id="T_248a8_level0_col2" class="col_heading level0 col2" >2060</th>
#       <th id="T_248a8_level0_col3" class="col_heading level0 col3" >Avg. annual change</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >County</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_248a8_level0_row0" class="row_heading level0 row0" >King</th>
#       <td id="T_248a8_row0_col0" class="data row0 col0" >2.41</td>
# ...

# %% [markdown]
# ## Vacancy Rate
#
# 1 - households / housing units.

# %%
show_region_ratio('hh', 'units', formula='vacancy', decimals=3)
# Out:
# ::: {.panel-tabset}
#
# ### Vision 2060 Scaled
#
# <style type="text/css">
# </style>
# <table id="T_d8e57">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d8e57_level0_col0" class="col_heading level0 col0" >2023</th>
#       <th id="T_d8e57_level0_col1" class="col_heading level0 col1" >2044</th>
#       <th id="T_d8e57_level0_col2" class="col_heading level0 col2" >2060</th>
#       <th id="T_d8e57_level0_col3" class="col_heading level0 col3" >Avg. annual change</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >County</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d8e57_level0_row0" class="row_heading level0 row0" >King</th>
#       <td id="T_d8e57_row0_col0" class="data row0 col0" >0.062</td>
# ...
