# %% [markdown]
# # Housing Units
#
# Housing-unit counts by target area and county. Derived in `calculate_units_for_dashboard.py` and persisted as `rebased_control_totals_units`. Spreadsheet forecasts have no units data.

# %%
from validation_data_input import show_indicator_county

# %% [markdown]
# ## King County

# %%
show_indicator_county('units', 53033)
# Out:
# ::: {.panel-tabset}
#
# ### Vision 2060 Scaled by County
#
# <style type="text/css">
# </style>
# <table id="T_4368e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4368e_level0_col0" class="col_heading level0 col0" >2023</th>
#       <th id="T_4368e_level0_col1" class="col_heading level0 col1" >2044</th>
#       <th id="T_4368e_level0_col2" class="col_heading level0 col2" >2060</th>
#       <th id="T_4368e_level0_col3" class="col_heading level0 col3" >Avg. annual change</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >target_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4368e_level0_row0" class="row_heading level0 row0" >Bellevue</th>
#       <td id="T_4368e_row0_col0" class="data row0 col0" >65,926</td>
# ...

# %% [markdown]
# ## Pierce County

# %%
show_indicator_county('units', 53053)
# Out:
# ::: {.panel-tabset}
#
# ### Vision 2060 Scaled by County
#
# <style type="text/css">
# </style>
# <table id="T_061c5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_061c5_level0_col0" class="col_heading level0 col0" >2023</th>
#       <th id="T_061c5_level0_col1" class="col_heading level0 col1" >2044</th>
#       <th id="T_061c5_level0_col2" class="col_heading level0 col2" >2060</th>
#       <th id="T_061c5_level0_col3" class="col_heading level0 col3" >Avg. annual change</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >target_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_061c5_level0_row0" class="row_heading level0 row0" >Tacoma</th>
#       <td id="T_061c5_row0_col0" class="data row0 col0" >94,569</td>
# ...

# %% [markdown]
# ## Snohomish County

# %%
show_indicator_county('units', 53061)
# Out:
# ::: {.panel-tabset}
#
# ### Vision 2060 Scaled by County
#
# <style type="text/css">
# </style>
# <table id="T_e2fbd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e2fbd_level0_col0" class="col_heading level0 col0" >2023</th>
#       <th id="T_e2fbd_level0_col1" class="col_heading level0 col1" >2044</th>
#       <th id="T_e2fbd_level0_col2" class="col_heading level0 col2" >2060</th>
#       <th id="T_e2fbd_level0_col3" class="col_heading level0 col3" >Avg. annual change</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >target_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e2fbd_level0_row0" class="row_heading level0 row0" >Everett</th>
#       <td id="T_e2fbd_row0_col0" class="data row0 col0" >48,487</td>
# ...

# %% [markdown]
# ## Kitsap County

# %%
show_indicator_county('units', 53035)
# Out:
# ::: {.panel-tabset}
#
# ### Vision 2060 Scaled by County
#
# <style type="text/css">
# </style>
# <table id="T_6dd68">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6dd68_level0_col0" class="col_heading level0 col0" >2023</th>
#       <th id="T_6dd68_level0_col1" class="col_heading level0 col1" >2044</th>
#       <th id="T_6dd68_level0_col2" class="col_heading level0 col2" >2060</th>
#       <th id="T_6dd68_level0_col3" class="col_heading level0 col3" >Avg. annual change</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >target_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6dd68_level0_row0" class="row_heading level0 row0" >Bremerton</th>
#       <td id="T_6dd68_row0_col0" class="data row0 col0" >18,539</td>
# ...
