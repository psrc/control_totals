# %% [markdown]
# # Households comparison - 2050
#
# Pairwise comparison of total households at **2050** between two forecasts, by control/target area and grouped by county.
#
# - **A**: Summer 2026 (pipeline)
# - **B (baseline)**: Legacy LUVit (RTP26) (spreadsheet)
#
# `% Diff = (A - B) / B * 100`.

# %%
from comparison_helpers import compare_hh_target_area, compare_hh_region

FORECAST_A = 'summer_2026'
FORECAST_B = 'legacy_luvit_rtp26'  # baseline (denominator)
YEAR = '2050'

# %% [markdown]
# ## Region

# %%
compare_hh_region(FORECAST_A, FORECAST_B, YEAR)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 compare_hh_region(FORECAST_A, FORECAST_B, YEAR)
#
# File c:\Users\JKolberg\PythonProjects\PSRC\control_totals\control_totals\validation\summary_scripts\comparison_helpers.py:185, in compare_hh_region(forecast_a_id, forecast_b_id, year, total_label)
#     178 def compare_hh_region(
#     179     forecast_a_id: str,
#     180     forecast_b_id: str,
#     181     year: str,
#     182     total_label: str = "Region",
#     183 ) -> "pd.io.formats.style.Styler":
#     184     """County-level HH comparison table at *year* with a Region row."""
# --> 185     a = _load_hh_year(forecast_a_id, year)
#     186     b = _load_hh_year(forecast_b_id, year)
#     187     if a is None or b is None:
#
# ...

# %% [markdown]
# ## King County

# %%
compare_hh_target_area(FORECAST_A, FORECAST_B, YEAR, 53033)
# Out:
# <style type="text/css">
# #T_17ecd th {
#   background-color: rgba(0,85,140,0.08);
#   font-weight: 600;
#   text-align: left;
# }
# #T_17ecd td {
#   padding: 4px 10px;
# }
# #T_17ecd_row0_col3, #T_17ecd_row1_col3, #T_17ecd_row2_col3, #T_17ecd_row3_col3, #T_17ecd_row4_col3, #T_17ecd_row5_col3, #T_17ecd_row7_col3, #T_17ecd_row8_col3, #T_17ecd_row9_col3, #T_17ecd_row10_col3, #T_17ecd_row12_col3, #T_17ecd_row13_col3, #T_17ecd_row14_col3, #T_17ecd_row15_col3, #T_17ecd_row16_col3, #T_17ecd_row17_col3, #T_17ecd_row18_col3, #T_17ecd_row19_col3, #T_17ecd_row20_col3, #T_17ecd_row21_col3, #T_17ecd_row22_col3, #T_17ecd_row23_col3, #T_17ecd_row24_col3, #T_17ecd_row25_col3, #T_17ecd_row26_col3, #T_17ecd_row29_col3, #T_17ecd_row30_col3, #T_17ecd_row31_col3, #T_17ecd_row33_col3, #T_17ecd_row34_col3, #T_17ecd_row38_col3, #T_17ecd_row39_col3, #T_17ecd_row40_col3, #T_17ecd_row43_col3, #T_17ecd_row45_col3, #T_17ecd_row51_col3, #T_17ecd_row52_col3, #T_17ecd_row55_col3, #T_17ecd_row56_col3 {
# ...

# %% [markdown]
# ## Pierce County

# %%
compare_hh_target_area(FORECAST_A, FORECAST_B, YEAR, 53053)
# Out:
# <style type="text/css">
# #T_0e3f6 th {
#   background-color: rgba(0,85,140,0.08);
#   font-weight: 600;
#   text-align: left;
# }
# #T_0e3f6 td {
#   padding: 4px 10px;
# }
# #T_0e3f6_row0_col3, #T_0e3f6_row1_col3, #T_0e3f6_row2_col3, #T_0e3f6_row3_col3, #T_0e3f6_row4_col3, #T_0e3f6_row7_col3, #T_0e3f6_row9_col3, #T_0e3f6_row10_col3, #T_0e3f6_row11_col3, #T_0e3f6_row12_col3, #T_0e3f6_row15_col3, #T_0e3f6_row16_col3, #T_0e3f6_row17_col3, #T_0e3f6_row18_col3, #T_0e3f6_row20_col3, #T_0e3f6_row21_col3, #T_0e3f6_row22_col3, #T_0e3f6_row24_col3, #T_0e3f6_row25_col3, #T_0e3f6_row26_col3 {
#   color: #b00020;
#   font-weight: 600;
# }
# #T_0e3f6_row5_col3, #T_0e3f6_row6_col3, #T_0e3f6_row13_col3, #T_0e3f6_row14_col3, #T_0e3f6_row19_col3, #T_0e3f6_row23_col3 {
#   color: #d97706;
# }
# #T_0e3f6_row8_col3 {
#   color: #2f7a2f;
# }
# </style>
# <table id="T_0e3f6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %% [markdown]
# ## Snohomish County

# %%
compare_hh_target_area(FORECAST_A, FORECAST_B, YEAR, 53061)
# Out:
# <style type="text/css">
# #T_36d6d th {
#   background-color: rgba(0,85,140,0.08);
#   font-weight: 600;
#   text-align: left;
# }
# #T_36d6d td {
#   padding: 4px 10px;
# }
# #T_36d6d_row0_col3, #T_36d6d_row1_col3, #T_36d6d_row2_col3, #T_36d6d_row3_col3, #T_36d6d_row5_col3, #T_36d6d_row7_col3, #T_36d6d_row8_col3, #T_36d6d_row9_col3, #T_36d6d_row12_col3, #T_36d6d_row13_col3, #T_36d6d_row15_col3, #T_36d6d_row16_col3, #T_36d6d_row19_col3, #T_36d6d_row20_col3, #T_36d6d_row24_col3, #T_36d6d_row26_col3, #T_36d6d_row28_col3, #T_36d6d_row32_col3, #T_36d6d_row34_col3, #T_36d6d_row37_col3, #T_36d6d_row38_col3, #T_36d6d_row41_col3, #T_36d6d_row42_col3, #T_36d6d_row43_col3, #T_36d6d_row44_col3 {
#   color: #b00020;
#   font-weight: 600;
# }
# ...

# %% [markdown]
# ## Kitsap County

# %%
compare_hh_target_area(FORECAST_A, FORECAST_B, YEAR, 53035)
# Out:
# <style type="text/css">
# #T_a34fb th {
#   background-color: rgba(0,85,140,0.08);
#   font-weight: 600;
#   text-align: left;
# }
# #T_a34fb td {
#   padding: 4px 10px;
# }
# #T_a34fb_row0_col3, #T_a34fb_row1_col3, #T_a34fb_row4_col3, #T_a34fb_row6_col3, #T_a34fb_row7_col3, #T_a34fb_row8_col3, #T_a34fb_row10_col3, #T_a34fb_row11_col3 {
#   color: #b00020;
#   font-weight: 600;
# }
# #T_a34fb_row2_col3, #T_a34fb_row5_col3, #T_a34fb_row9_col3 {
#   color: #2f7a2f;
# }
# #T_a34fb_row3_col3 {
#   color: #d97706;
# }
# </style>
# <table id="T_a34fb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a34fb_level0_col0" class="col_heading level0 col0" >Summer 2026</th>
#       <th id="T_a34fb_level0_col1" class="col_heading level0 col1" >Legacy LUVit (RTP26)</th>
#       <th id="T_a34fb_level0_col2" class="col_heading level0 col2" >Diff</th>
#       <th id="T_a34fb_level0_col3" class="col_heading level0 col3" >% Diff</th>
#     </tr>
#   </thead>
# ...

# %% [markdown]
# ## Notes
#
# - `% Diff` is computed as `(A - B) / B * 100`, where **B** (baseline) is the
#   second forecast listed at the top of the notebook.
# - Cell color: red when `|% Diff| >= 5%`, amber when `>= 2.5%`, green otherwise.
# - Target areas present in only one forecast still appear, with `-` for the
#   missing forecast's value.
